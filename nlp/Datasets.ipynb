# %% [markdown]
# Purpose:
# - pre‑training<br>no labeling required, just proper cleaning. ideal for self-supervised training
# - instruction following<br>contains examples how to follow text instructions
# - fine‑tuning<br>high-level tasks
# - human preferences<br>used for alignment of pre-trained models (what is a "good" and a "bad" answer) using RL
# - evaluation (benchmarks)<br>
# - old NLP datasets<br>not very suitable for training large-scale LLMs
#
# By domain:
# - general
# - domain-specific
#
# By language:
# - Monolingual
# - Multilingual
#
# By Modality:
# - Multimodal
#
# General purpose datasets:
# - 60% web dumps (Common Crawl)
# - 10% social media
# - 15% books
# - 10% code (e.g., GitHub),
# - 5% scientific articles
#
# Domain-specific
# - Legal
# - Medical
# - Finance
#
# Languages
# - English
# - Chinese
# - Spanish
#
# Instruction datasets
# - hunman written
# - model generated
# - curated
# - hybrid
#
# Task types:
# - classification
# - summarization
# - QA
# - translation
# - code generation
#
# Preference data:
# - ratings
# - rankings
# - pairwise comparisons
#
# WebGPT 300K
#
# Evaluation
# - factuality
# - reasoning
# - safety
#
# Legacy
# - GLUW
# - SQuAD
# - CNN
# - XNLI

# %% [markdown]
# Mindmap of the dataset exploration:
# <img src="img/datasets_overview.png">

# %% [markdown]
# # Some popular datasets
#
# |Dataset|Size|Tokens (B)|Source|Used By|Notes|Release Year|
# |:---|:---|:---|:---|:---|:---|:---|
# |Wikipedia (English)|20GB|6|Wikipedia dump|Most models|High-quality factual data|2001|
# |Wikipedia (All Langs)|300GB|100|All language editions|LLaMA, Gopher, mT5	Standard multilingual resource|2018|
# |Common Crawl|60TB|10000B|Web crawl (monthly snapshots)|GPT-3, LLaMA, PaLM, Gopher|Filtered and deduplicated; a major component in many LLMs|2013|
# |The Pile|825GB|570|Books, Wikipedia, GitHub, arXiv, StackExchange, PubMed, etc.|GPT-J, GPT-NeoX|Curated by EleutherAI; open-source, diverse English corpus|2020|
# |C4|750GB|365|Filtered Common Crawl|T5, PaLM|English-only, cleaned web pages|2020|
# |MC4|1.5TB|1000|Multilingual C4 from Common Crawl|mT5, PaLM-2|Multilingual, deduplicated version of C4|2020|
# |Dolma|3TB|1000|Web, academic, code, StackExchange|OLMo|Modern open-source alternative to Common Crawl|2024|
# |OpenWebText|40GB|38|Web pages referenced on Reddit|GPT-2, Falcon	Mimics|GPT-2 training data|2019|
# |Books3|196GB|109|Books (pirated via Bibliotik)|GPT-J, LLaMA|Removed due to DMCA; controversial|2017|
# |Books1/BooksCorpus|30GB|15|Free/open book texts|GPT-2, RoBERTa|Used in early models, less controversial|2018|
#
# S2ORC	600	81	Open scientific papers	Galactica	Structured scientific papers with metadata	2020
#
# StackExchange Dump	80	30	Technical Q&A forums	GPT-J, Mistral	Technical discussion and reasoning data	2020
#
# GitHub / StackOverflow / CodeSearchNet	200	100	Code repositories and Q&A	Code models: CodeX, StarCoder, LLaMA 2	Used in code-specialized and general LLMs	2020
#
# WBNS	250	125	Wikipedia + Books + News	Gemini, Gopher	Internal aggregate for grounding knowledge	2021
# ArXiv / PubMed	50	25	Scientific papers	GPT-NeoX, BioGPT, Galactica	Scientific reasoning and language	2021
#
# RefinedWeb	10000	10000	Cleaned Common Crawl	Falcon, Mistral	Strong filtering pipeline from LAION	2022
#
# Math Datasets (GSM8k, MATH, etc.)	10	5	Textbook-level math problems	Minerva, Claude, Gemini	Used for math reasoning tasks	2022
#
# RedPajama	5000	1000	Reproduced LLaMA dataset	OpenLLaMA	Open-source replica of LLaMA’s training data	2023
#
# GithubCode (filtered)	200	80	GitHub code repos	StarCoder, CodeLLaMA	Filtered for license and quality	2023
#
# BigCode (StarCoder)	800	300	Curated open code	StarCoder	Includes GitHub + structured code	2023

# %% [markdown]
# YandexGPT
#
# 30% Russian
# 60% web, 15+10 code and math
